# %%
#SRIM
f = open("C1000chu.out",'r') #variável do arquivo de leitura
g = open("C1000chu.txt",'w')    #variável do arquivo de escrita
g.close()
linhas = f.readlines()
h = linhas[62:162]
#print(h)

with open('C1000chu.txt','w') as g:
    for i in range(len(h)):
        print(h[i], end ='\n',file=g)
        

g.close()
f.close()

# %%
import matplotlib.pyplot 

SMALL_SIZE = 19
MEDIUM_SIZE = 25
BIGGER_SIZE = 30

 

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

 

matplotlib.rcParams['font.family'] = "serif"

 


matplotlib.rcParams['xtick.major.size'] = 5
matplotlib.rcParams['xtick.major.width'] = 3
matplotlib.rcParams['xtick.minor.size'] = 4
matplotlib.rcParams['xtick.minor.width'] = 2
matplotlib.rcParams['ytick.major.size'] = 5
matplotlib.rcParams['ytick.major.width'] = 3
matplotlib.rcParams['axes.linewidth'] = 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics
plt.figure(figsize=(30,25))

dx, i =np.loadtxt("H100chu.txt",unpack=True)
plt.subplot(321)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("100keV -Chu")
y_tick = np.arange(0,140,20,)
plt.yticks(y_tick)
plt.ylim(0,140)
#x_tick = np.arange(0,2.75e+08,1e+02)
#plt.xticks(x_tick)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))


plt.legend()

dx, i =np.loadtxt("H500chu.txt",unpack=True)
plt.subplot(322)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("500keV -Chu")
y_tick = np.arange(0,140,20)
plt.yticks(y_tick)
plt.ylim(0,140)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

plt.legend()

dx, i =np.loadtxt("H1000chu.txt",unpack=True)
plt.subplot(323)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("1000keV -Chu")
y_tick = np.arange(0,140,20)
plt.yticks(y_tick)
plt.ylim(0,140)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

plt.legend()

dx, i =np.loadtxt("H100bohr.txt",unpack=True)
plt.subplot(324)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("100keV -Bohr")
y_tick = np.arange(0,140,20)
plt.yticks(y_tick)
plt.ylim(0,140)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))
plt.legend()

dx, i =np.loadtxt("H500bohr.txt",unpack=True)
plt.subplot(325)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("500keV -Bohr")
y_tick = np.arange(0,140,20)
plt.yticks(y_tick)
plt.ylim(0,140)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

plt.legend()

dx, i =np.loadtxt("H1000bohr.txt",unpack=True)
plt.subplot(326)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("1000keV -Bohr")
y_tick = np.arange(0,140,20)
plt.yticks(y_tick)
plt.ylim(0,140)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

plt.legend()


plt.savefig("final.jpg", bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Média: 9603.0 Variância amostral: 30422304.0 desvio-padrão amostral: 5515.641757764911
# Média: 45000.0 Variância amostral: 668250000.0 desvio-padrão amostral: 25850.53190942113
# Média: 126000.0 Variância amostral: 5239080000.0 desvio-padrão amostral: 72381.48934637917
# Média: 9500.0 Variância amostral: 29782500.0 desvio-padrão amostral: 5457.3345142111275
# Média: 45000.0 Variância amostral: 668250000.0 desvio-padrão amostral: 25850.53190942113
# Média: 130000.0 Variância amostral: 5577000000.0 desvio-padrão amostral: 74679.31440499437

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(30,25))

dx, i =np.loadtxt("H100sem.txt",unpack=True)
plt.subplot(321)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("100keV -sem")
y_tick = np.arange(0,160,20)
plt.yticks(y_tick)
plt.ylim(0,160)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))
plt.legend()

dx, i =np.loadtxt("H500sem.txt",unpack=True)
plt.subplot(322)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("500kev -sem")
y_tick = np.arange(0,160,20)
plt.yticks(y_tick)
plt.ylim(0,160)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))
plt.legend()

dx, i =np.loadtxt("H1000sem.txt",unpack=True)
plt.subplot(323)
plt.plot(dx/10000,i)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("1000keV -sem")
y_tick = np.arange(0,160,20)
plt.yticks(y_tick)
plt.ylim(0,160)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))
plt.legend()







plt.savefig("finalsemS.jpg", bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Média: 8400.0 Variância amostral: 23284800.0 desvio-padrão amostral: 4825.432623091944
# Média: 44500.0 Variância amostral: 653482500.0 desvio-padrão amostral: 25563.30377709423
# Média: 123000.0 Variância amostral: 4992570000.0 desvio-padrão amostral: 70658.12055241775

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics
plt.figure(figsize=(30,25))

plt.subplot(321)
dx, i =np.loadtxt("testetc3.txt",unpack=True)
plt.plot(dx/10000,i, label='Chu',color='red')
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

dx, i =np.loadtxt("testetc6.txt",unpack=True)
plt.plot(dx/10000,i,label ='Bohr',color='blue')
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

dx,i = np.loadtxt("Tc.txt",unpack=True)
plt.plot(abs(dx/10000),i,label='Energias maiores programa',color='purple')


dx, i =np.loadtxt("testetc9.txt",unpack=True)
plt.plot(dx/10000,i,label ='sem',color='green')

plt.title(" comparação 1MeV")
y_tick = np.arange(0,160,20)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.yticks(y_tick)
plt.grid()
plt.ylim(0,100)
plt.xlim(10,27.5)
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))
plt.legend()

###############################################################################################################3
plt.subplot(322)
dx, i =np.loadtxt("testetc2.txt",unpack=True)
plt.plot(dx/10000,i,label="Chu",color='red')
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

dx, i =np.loadtxt("testetc5.txt",unpack=True)
plt.plot(dx/10000,i,label='Bohr',color='blue')
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

dx, i =np.loadtxt("testetc8.txt",unpack=True)
plt.plot(dx/10000,i,label='Sem',color='green')
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("Comparação 500keV")
y_tick = np.arange(0,160,20)
plt.yticks(y_tick)
plt.ylim(0,160)
plt.xlim(5,10)
plt.grid()
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))
plt.legend()
##############################################################################################################
plt.subplot(323)
dx, i =np.loadtxt("testetc1.txt",unpack=True)
plt.plot(dx/10000,i,label='Chu',color='red')
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

dx, i =np.loadtxt("testetc4.txt",unpack=True)
plt.plot(dx/10000,i, label='Bohr',color='blue')
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

dx, i =np.loadtxt("testetc7.txt",unpack=True)
plt.plot(dx/10000,i,label='Sem',color='green')
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("Comparação 100 keV")
y_tick = np.arange(0,160,20)
plt.yticks(y_tick)
plt.ylim(0,120)
plt.xlim(0.75,2)
plt.grid()
plt.legend()
print("Média:",statistics.mean(dx),"Variância amostral:",statistics.variance(dx),"desvio-padrão amostral:",statistics.stdev(dx))

plt.savefig("ComparaçãoFortran.jpg",bbox_inches='tight')
# Out:
# Média: 126000.0 Variância amostral: 5239080000.0 desvio-padrão amostral: 72381.48934637917
# Média: 130000.0 Variância amostral: 5577000000.0 desvio-padrão amostral: 74679.31440499437
# Média: 123000.0 Variância amostral: 4992570000.0 desvio-padrão amostral: 70658.12055241775
# Média: 45000.0 Variância amostral: 668250000.0 desvio-padrão amostral: 25850.53190942113
# Média: 45000.0 Variância amostral: 668250000.0 desvio-padrão amostral: 25850.53190942113
# Média: 44500.0 Variância amostral: 653482500.0 desvio-padrão amostral: 25563.30377709423
# Média: 9603.0 Variância amostral: 30422304.0 desvio-padrão amostral: 5515.641757764911
# Média: 9500.0 Variância amostral: 29782500.0 desvio-padrão amostral: 5457.3345142111275
# Média: 8400.0 Variância amostral: 23284800.0 desvio-padrão amostral: 4825.432623091944

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics

plt.figure(figsize=(30,25))




D,S,R,T = np.loadtxt('SRIM1000.txt',unpack=True)
DC,SC,R,T = np.loadtxt('SRIMC1000.txt',unpack=True)
DHe,SHe,R,T = np.loadtxt('SRIMHe1000.txt',unpack=True)
plt.subplot(321)
plt.plot(S/10000,D,'o',color='red')
plt.plot(SC/10000,DC,'o',label='Carbono')
plt.plot(SHe/10000,DHe,'o',color='green',label='Hélio')
plt.xlim(0.1,28)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("Comparação 1000 keV")
plt.legend()
plt.grid()

D3,S3,R,T = np.loadtxt('SRIM100.txt',unpack=True)
plt.subplot(322)
plt.plot(S3/10000,D3,'o')
plt.xlim(0.8,1.8)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("Comparação 100 keV")
plt.grid()


D3,S3,R,T = np.loadtxt('SRIM500.txt',unpack=True)
plt.subplot(323)
plt.plot(S3/10000,D3,'o')
plt.xlim(8,10)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("Comparação 500 keV")
plt.grid()

plt.savefig("TRIM.jpg",bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(30,25))


D,S,R,T = np.loadtxt('SRIM1000.txt',unpack=True)

plt.subplot(321)
plt.hist(S/10000,40)
plt.xlim(24,28)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("Comparação 1000 keV")
#plt.grid()

D3,S3,R,T = np.loadtxt('SRIM100.txt',unpack=True)
plt.subplot(322)
plt.hist(S3/10000,40)
plt.xlim(0.8,1.8)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("Comparação 100 keV")
#plt.grid()


D3,S3,R,T = np.loadtxt('SRIM500.txt',unpack=True)
plt.subplot(323)
plt.hist(S3/10000,40)
plt.xlim(8,10)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.title("Comparação 500 keV")
#plt.grid()

plt.savefig("TRIM2.jpg",bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics
plt.figure(figsize=(30,25))

plt.subplot(321)
dx, i =np.loadtxt("H1000chu.txt",unpack=True)
plt.plot(dx/10000,i, label='Proton',color='red')


dx, i =np.loadtxt("He1000chu.txt",unpack=True)
plt.plot(dx/10000,i,label ='Hélio',color='blue')


dx,i = np.loadtxt("C1000chu.txt",unpack=True)
plt.plot(abs(dx/10000),i,label='Carbono',color='purple')


plt.title("comparação 1MeV")
y_tick = np.arange(0,160,20)
plt.xlabel("x ($\mu$m)")
plt.ylabel("N íons")
plt.yticks(y_tick)
plt.grid()
plt.ylim(0,180)
plt.xlim(0.01,27.5)
plt.legend()
